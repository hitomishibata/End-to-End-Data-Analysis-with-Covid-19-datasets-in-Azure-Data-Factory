# %%
# %run "../include/configuration"

# %%
from pyspark.sql.types import *

# %%
test_schema = StructType(fields=[StructField("country", StringType(), False),
                                     StructField("country_code", StringType(), False),
                                     StructField("year_week", StringType(), False),
                                     StructField("level", StringType(), True),
                                     StructField("region", StringType(), True),
                                     StructField("region_name", StringType(), True),
                                     StructField("new_cases", IntegerType(), True),
                                     StructField("tests_done", IntegerType(), True),
                                     StructField("population", IntegerType(), True),
                                     StructField("testing_rate", DoubleType(), True),
                                     StructField("positivity_rate", DoubleType(), True),
                                     StructField("testing_data_source", StringType(), True)])

# %%
test_df = spark.read.option("header", True).schema(test_schema).csv(f"{raw_covid_folder_path}/test.csv")

# %%
lookup_date_df = spark.read.option("header", True).csv(f"{raw_covid_folder_path}/lookup/dim_date.csv")

# %%
from pyspark.sql.functions import *

# %%
year_week_lookup_df = lookup_date_df.withColumn("year_week_1", regexp_replace(col("year_week"), "(\\d{4})(\\d{2})", "$1-W$2"))

# %%
year_week_lookup_df = year_week_lookup_df.groupBy("year_week_1").agg(min(col("date")).alias("week_first_date"), max(col("date")).alias("week_last_date"))

# %%
joined_test_df = test_df.join(year_week_lookup_df, test_df.year_week == year_week_lookup_df.year_week_1)

# %%
final_test_df = joined_test_df.select(col("year_week"), col("week_first_date"), col("week_last_date"), col("country"), col("country_code").alias("country_code_2_digit"), col("population"), col("new_cases"), col("tests_done"), col("testing_rate"), col("positivity_rate"), col("testing_data_source")).orderBy(desc("year_week"))

# %%
display(final_test_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year_week</th><th>week_first_date</th><th>week_last_date</th><th>country</th><th>country_code_2_digit</th><th>population</th><th>new_cases</th><th>tests_done</th><th>testing_rate</th><th>positivity_rate</th><th>testing_data_source</th></tr></thead><tbody><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Austria</td><td>AT</td><td>8978929</td><td>24803</td><td>null</td><td>null</td><td>null</td><td>NA</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Belgium</td><td>BE</td><td>11617623</td><td>6078</td><td>388</td><td>3.3397537516925793</td><td>null</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Bulgaria</td><td>BG</td><td>6838937</td><td>877</td><td>10751</td><td>157.2027933580906</td><td>8.157380708771278</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Croatia</td><td>HR</td><td>3862305</td><td>5207</td><td>34483</td><td>892.8088278890456</td><td>15.10019429863991</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Cyprus</td><td>CY</td><td>904705</td><td>2756</td><td>53938</td><td>5961.943395913585</td><td>5.109570247320998</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Czechia</td><td>CZ</td><td>10516707</td><td>2699</td><td>26369</td><td>250.73437911696124</td><td>10.235503811293565</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Denmark</td><td>DK</td><td>5873420</td><td>6792</td><td>41663</td><td>709.348216201123</td><td>16.302234596644503</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Estonia</td><td>EE</td><td>1331796</td><td>541</td><td>14639</td><td>1099.1923688012278</td><td>3.6956076234715485</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Finland</td><td>FI</td><td>5548241</td><td>4246</td><td>21730</td><td>391.6556616772775</td><td>19.539806718821904</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>France</td><td>FR</td><td>67871925</td><td>154693</td><td>790720</td><td>1165.0177890195394</td><td>19.563562322946176</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Germany</td><td>DE</td><td>83237124</td><td>151567</td><td>309850</td><td>372.24976682279413</td><td>48.91624979828949</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Greece</td><td>EL</td><td>10459782</td><td>34711</td><td>487578</td><td>4661.454703358062</td><td>7.119066077632707</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Hungary</td><td>HU</td><td>9689010</td><td>2921</td><td>8290</td><td>85.5608570947909</td><td>35.23522316043426</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Iceland</td><td>IS</td><td>376248</td><td>223</td><td>615</td><td>163.45601837086178</td><td>36.260162601626014</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Ireland</td><td>IE</td><td>5060004</td><td>2802</td><td>17423</td><td>344.32779104522444</td><td>16.082190208345292</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Italy</td><td>IT</td><td>59030133</td><td>133380</td><td>null</td><td>null</td><td>null</td><td>NA</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Latvia</td><td>LV</td><td>1875757</td><td>1327</td><td>7050</td><td>375.8482575301598</td><td>18.822695035460992</td><td>TESSy COVID-19</td></tr><tr><td>2022-W52</td><td>2022-12-18</td><td>2022-12-24</td><td>Liechtenstein</td><td>LI</td><td>39308</td><td>19</td><td>139</td><td>353.6175842067772 ...

# %%
final_test_df.write.mode("overwrite").parquet(f"{processed_covid_folder_path}/tests")

# %%
test_df = spark.read.option("header", True).parquet(f"{processed_covid_folder_path}/tests")

# %%
# %sql
USE covid_19
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DROP TABLE covid_19.tests

# %%
test_df.write.format("parquet").saveAsTable("tests")
